# %%
try:
    a = int(input("割られる数を入力してください："))
    b = int(input("割る数を入力してください："))
    c = a / b
    print(f"{a} ÷ {b} = {c}")
except ValueError:
    print("数値を入力してください")
except ZeroDivisionError:
    print("0で割り算しないでください")

print("処理を終了します")
# Out:
# 100 ÷ 2 = 50.0
# 処理を終了します
